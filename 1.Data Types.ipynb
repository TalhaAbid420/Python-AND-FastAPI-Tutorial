# %% [markdown]
# # Python Data Types for Beginners
#
# In Python, every piece of data is an object. Understanding Python’s built-in data types is fundamental for writing efficient, readable, and bug-free programs. This notebook will introduce you to Python’s core data types and show you best practices on how to work with them.

# %% [markdown]
# # 1. Numeric Types
#
# Python has three main numeric data types:
#
# ### 1. Integer (`int`)
# Whole numbers without a fractional component.
# **Examples:** `0`, `1`, `-5`, `999`, `42`, `-10`
#
# ### 2. Float (`float`)
# Numbers with decimal points or in exponential form.
# **Examples:** `3.14`, `2.7e3`, `-0.001`
#
# ### 3. Complex (`complex`)
# Numbers with both real and imaginary parts.
# **Examples:** `2+3j`, `-1.5+2.7j`

# %% [markdown]
# ## 1.1 Integers
# **Definition**: Integers are whole numbers without a fractional component.
# **Examples:** -10, 0, 42.

# %%
# Example of Integers

num1 = 42
num2 = -7
num3 = 0

print("Integer Examples:")
print("num1:", num1, type(num1))
print("num2:", num2, type(num2))
print("num3:", num3, type(num3))
# Out:
# Integer Examples:
# num1: 42 <class 'int'>
# num2: -7 <class 'int'>
# num3: 0 <class 'int'>

# %% [markdown]
# ### Best Practices:
# 1. Use descriptive variable names: Instead of x or y, use user_age or items_count.
#
# 2. Handle potential overflow: In Python 3, integers are of unlimited size (limited by available memory), so you rarely need to worry about overflow.
#
# 3. Avoid ambiguous naming: For example, O (capital letter O) or l (lowercase L) can be confused with numbers.

# %% [markdown]
# ## 1.2 Floats
#
# **Definition:** Floats represent real numbers that include a fractional component.
# **Examples:** 3.14159, -0.001, 1.5e2 (which equals 150.0).

# %%
# Example of floats

pi = 3.14159
small_float = -0.001
large_float = 1.5e2  # which equals 150.0

print("\nFloat Examples:")
print("pi:", pi, type(pi))
print("small_float:", small_float, type(small_float))
print("large_float:", large_float, type(large_float))
# Out:
# Float Examples:
# pi: 3.14159 <class 'float'>
# small_float: -0.001 <class 'float'>
# large_float: 150.0 <class 'float'>

# %% [markdown]
# ### Best Practices:
# 1. Watch out for floating-point precision issues. Use decimal or fractions modules if you need precise decimal arithmetic (e.g., currency calculations).
# 2. Use underscores for large numbers: Python 3.6+ allows underscores in numeric literals for readability, e.g., 1_000_000.0 instead of 1000000.0.
# 3. Check your computations: Floating-point arithmetic can lead to subtle bugs in equality checks. Prefer a tolerance-based approach if comparing floats, for example:
# python
# Copy

# %% [markdown]
# # 2. Strings
#
# **Definition:** A string is a sequence of characters. In Python, strings can be enclosed in single quotes ('...'), double quotes ("..."), or triple quotes ('''...''' or """...""") for multi-line strings.
#
# **Examples:** "Hello World", 'Python is great!', """Triple quoted strings can span multiple lines""".

# %%
# Examples of strings

greeting = "Hello World"
quote = 'Python is great!'
multi_line = """
Triple quoted strings can span 
multiple lines
"""

print("\nString Examples:")
print("greeting:", greeting, type(greeting))
print("quote:", quote, type(quote))
print("multi_line:", multi_line, type(multi_line))
# Out:
# String Examples:
# greeting: Hello World <class 'str'>
# quote: Python is great! <class 'str'>
# multi_line:
# Triple quoted strings can span
# multiple lines
#  <class 'str'>

# %% [markdown]
# ## String Operations

# %%
# Concatenation
first_name = "John"
last_name = "Doe"
full_name = first_name + " " + last_name

# Repitition
ha_3_times = "Ha" * 3

#Indexing and Slicing
first_char = greeting[0]
substring1 = greeting[0:5]
substring2 = greeting[6:]

print(full_name)
print("ha 3 times:", ha_3_times)
print("first character:", first_char)
print("Substring 1:", substring1)
print("Substring 2:", substring2)
# Out:
# John Doe
# ha 3 times: HaHaHa
# first character: H
# Substring 1: Hello
# Substring 2: World

# %% [markdown]
# ### Best Practices:
#
# 1. Use f-strings (formatted strings) for readability (Python 3.6+)

# %%
# Example
age = 25
print(f"My age is {age}.")

# continue..
name = "Talha Abid"
Intro = f"My name is {name} and I am {age} year's old."

print(f"My Introduction: {Intro}")
# Out:
# My age is 25.
# My Introduction: My name is Talha Abid and I am 25 year's old.

# %% [markdown]
# # 3. Boolean Type
#
# **Definition:** Booleans are True or False values.
# **Use:** Typically used in condition checks, loops, or logical evaluations.

# %%
# Example
is_python_hard = False
likes_coffe = True

print(f"Is Python Hard? : {is_python_hard}.\n", type(is_python_hard))
print(f"Does Talha like coffee? : {likes_coffe}. \n", type(likes_coffe))
# Out:
# Is Python Hard? : False.
#  <class 'bool'>
# Does Talha like coffee? : True.
#  <class 'bool'>

# %% [markdown]
# ### Best Practices:
#
# 1. *Use descriptive names:* Instead of flag or status, use is_active or has_errors.
# 2. Avoid comparing booleans to True or False directly
# 3. *Keep booleans purely boolean:* Resist the temptation to mix them with numbers. Although True behaves like 1 and False like 0, it makes the code less clear.

# %%
# Instead of: if is_python_easy == True:
# Do this:
if likes_coffe:
    print("Yes, Talha likes coffee!")
# Out:
# Yes, Talha likes coffee!

# %% [markdown]
# # 4. NoneType
#
# **Definition:** None represents the absence of a value.
# **Use:** Often used as a placeholder for optional or missing data.

# %%
nothing_here = 2
print("Nothing here:", nothing_here, type(nothing_here))
# Out:
# Nothing here: 2 <class 'int'>

# %% [markdown]
# ### Best Practices:
#
# 1. Check for None with is None rather than == None

# %%
if nothing_here is None:
    print("This variable has no value.")

if nothing_here is not None:
    print("This variable has value.")
# Out:
# This variable has value.

# %% [markdown]
# # 5. Collections Overview
#
# While primitive data types (like int, float, bool, and str) hold single values, Python’s built-in collections let you group multiple items in flexible ways. The four primary built-in collections are:
#
# 1. List – An ordered, mutable sequence.
# 2. Tuple – An ordered, immutable sequence.
# 3. Dictionary – An unordered set of key-value pairs.
# 4. Set – An unordered collection of unique elements.
#
# Below, we’ll explore each in depth with code examples and best practices.

# %% [markdown]
# ### 5.1 List
#
# **Definition & Characteristics**
#
# 1. A list is created using square brackets [] or the list() constructor.
# 2. It is ordered, meaning elements retain the order in which they’re inserted.
# 3. It is mutable: You can add, remove, or modify elements after creation.

# %%
# Creating lists in different ways

empty_list = []
Words = ["yep", "yes", "nah", "oops"]
numbers = [10, 20, 30, 40, 50]
mixed_list = ["Hello", 200, True]

print(f"Empty list: {empty_list}")
print(f"Numbers list: {numbers}")
print(f"Words list: {Words}")
print(f"Mixed list: {mixed_list}")

# Accessing elements by index from lists
first_num = numbers[0]
last_num = numbers[-1]
sublist = numbers[1:4]

print(f"\nFirst Number: {first_num}")
print(f"Last Number: {last_num}")
print(f"Numbers from within the list: {sublist}")
# Out:
# Empty list: []
# Numbers list: [10, 20, 30, 40, 50]
# Words list: ['yep', 'yes', 'nah', 'oops']
# Mixed list: ['Hello', 200, True]
#
# First Number: 10
# Last Number: 50
# Numbers from within the list: [20, 30, 40]

# %% [markdown]
# *Adding, Removing, and Modifying Elements*

# %%
# Adding Elements

print(f"Numbers List: {numbers}")

numbers.append(60)       # Inserts element 60 at the end of the list
print(f"Numbers List: {numbers}")

numbers.insert(2, 25)    # Inserts element 25 at index 2
print(f"Numbers List: {numbers}")


# Removing Elements

removed_item = numbers.pop()    # removes the last element and stores that element
print(f"Removed Element: {removed_item}")
print(f"Numbers List: {numbers}")

numbers.remove(25)      # removes the first occurence of 25.
print(f"Numbers List: {numbers}")

# Modifying the list

numbers[1] = 15
print(f"Numbers List: {numbers}")
# Out:
# Numbers List: [10, 20, 30, 40, 50]
# Numbers List: [10, 20, 30, 40, 50, 60]
# Numbers List: [10, 20, 25, 30, 40, 50, 60]
# Removed Element: 60
# Numbers List: [10, 20, 25, 30, 40, 50]
# Numbers List: [10, 20, 30, 40, 50]
# Numbers List: [10, 15, 30, 40, 50]

# %% [markdown]
# ### 5.2 Tuple
#
# **Definition & Characteristics**
#
# 1. A tuple is created using parentheses () or the tuple() constructor.
# 2. It is ordered, similar to a list.
# 3. It is immutable: You cannot add, remove, or change elements once defined.
#
# *Creation & Basic Operations*

# %%
# Creating tuples

empty_tuple = ()
single_element_tuple = (42, )
numbers_tuple = (10, 20, 30, 40, 50)
mixed_tuple = ("hello", 50, True)

print(f"Empty tuple: {empty_tuple}")
print(f"Single element  tuple: {single_element_tuple}")
print(f"Numbers tuple: {numbers_tuple}")
print(f"Mixed tuple: {mixed_tuple}")

# Accessing elements by index

first_item = numbers_tuple[0]
print(f"\nFirst tuple element: {first_item}")

# Slicing on tuples works similar to lists
sub_tuple = numbers_tuple[2: 4]
print(f"Elements from tuple: {sub_tuple}")
# Out:
# Empty tuple: ()
# Single element  tuple: (42,)
# Numbers tuple: (10, 20, 30, 40, 50)
# Mixed tuple: ('hello', 50, True)
#
# First tuple element: 10
# Elements from tuple: (30, 40)

# %% [markdown]
# Immutability

# %%
# Trying to modify a tuple will raise an error
try:
    numbers_tuple[1] = 99       # This isn't allowed
except TypeError as e:
    print(f"Error: {e}")
# Out:
# Error: 'tuple' object does not support item assignment

# %%
# Unpacking tuple into separate variables

person_tuple = ("Bob", 35, "Driver")
name, age, job = person_tuple

print(f"Name: {name}")
print(f"Age: {age}")
print(f"Job: {job}")
# Out:
# Name: Bob
# Age: 35
# Job: Driver

# %% [markdown]
# Best Practices for Tuples
#
# 1. Use tuples for fixed collections of items that don’t change, like coordinates or constant data.
# 2. Leverage tuple unpacking to write cleaner code when returning multiple values from a function.
# 3. Don’t modify: If you need to frequently alter the collection, consider a list.

# %% [markdown]
# ### 5.3 Dictionary
#
# **Definition & Characteristics**
#
# 1. A dictionary is created using curly braces {} with key-value pairs, or using dict() constructor.
# 2. It is unordered (though Python 3.7+ maintains insertion order as an implementation detail).
# 3. Keys must be unique and immutable (e.g., strings, numbers, tuples). Values can be anything.
# 4. t is mutable: You can add, remove, or change key-value pairs.

# %% [markdown]
# Creation & Basic Operations

# %%
# Creating Dictionaries

empty_dict = {}
person_dict = {"name": "Talha", "age": 23, "likes_coffee": True}
location_dict = {"city": "Multan", "country": "Pakistan"}

print(f"Empty Dictionary: {empty_dict}")
print(f"Person Dictionary: {person_dict}")
print(f"Location Dictionary: {location_dict}")

# Accessing Values by key
print("Person name:",person_dict["name"])
print("Person age:",person_dict.get("age"))     # .get() is safer, returns None if key isn't found
print(f"Person location: {location_dict['city']}, {location_dict['country']}")
# Out:
# Empty Dictionary: {}
# Person Dictionary: {'name': 'Talha', 'age': 23, 'likes_coffee': True}
# Location Dictionary: {'city': 'Multan', 'country': 'Pakistan'}
# Person name: Talha
# Person age: 23
# Person location: Multan, Pakistan

# %% [markdown]
# *Adding, Updating, and Removing Keys*

# %%
# Adding or updating/modifying a key-value pair

person_dict['city'] = "New York"    # adds city if it doesn't exist, else updates it
print(f"Person Dictionary: {person_dict}")

# Removing a key-value pair
removed_value = person_dict.pop("age")      # Removes 'age' and returns its value
print(f"Removed Age: {removed_value}")
print(f"Person Dictionary: {person_dict}")

# Checking if a key exists in dictionary
if "color" in person_dict:
    print("Name key is present.")

print(f"Person Dictionary: {person_dict}")
# Out:
# Person Dictionary: {'name': 'Talha', 'age': 23, 'likes_coffee': True, 'city': 'New York'}
# Removed Age: 23
# Person Dictionary: {'name': 'Talha', 'likes_coffee': True, 'city': 'New York'}
# Person Dictionary: {'name': 'Talha', 'likes_coffee': True, 'city': 'New York'}

# %%
# Printing keys, values and items

print(f"Keys: {person_dict.keys()}")
print(f"Values: {person_dict.values()}")
print(f"Items: {person_dict.items()}")
# Out:
# Keys: dict_keys(['name', 'likes_coffee', 'city'])
# Values: dict_values(['Talha', True, 'New York'])
# Items: dict_items([('name', 'Talha'), ('likes_coffee', True), ('city', 'New York')])

# %% [markdown]
# Best Practices for Dictionaries
#
# 1. Use dictionaries when you need fast lookups by key.
# 2. Keys should be immutable and descriptive (e.g., strings that convey meaning).
# 3. Use .get(key, default) to avoid KeyError when a key might not exist.
# 4. Dictionaries are great for configuration data, or bundling related data attributes without creating a custom class.

# %% [markdown]
# ### 5.4 Set
#
# Definition & Characteristics
#
# 1. A set is created using curly braces {} or the set() constructor.
# 2. It is unordered and does not allow duplicate elements.
# 3. It is mutable: You can add or remove elements.
#
#
# Creation & Basic Operations

# %%
# Creating Sets

empty_set = {}
numbers_set = {10, 20, 30, 40, 20}      # duplicates are removed automatically
mixed_set = {"apple", 50, (1, 3)}       # You can also store immutable types like tuples in a set

print(f"Empty Set: {empty_set}")
print(f"Numbers Set: {numbers_set}")
print(f"Mixed Set: {mixed_set}")
# Out:
# Empty Set: {}
# Numbers Set: {40, 10, 20, 30}
# Mixed Set: {50, (1, 3), 'apple'}

# %% [markdown]
# *Adding and Removing Elements*

# %%
numbers_set.add(60)        # Adds 4 to the set
print(f"Numbers set: {numbers_set}")

numbers_set.discard(20)    # Removes 2 if it exists, no error if it doesn’t
# numbers_set.remove(2)   # Removes 2 but raises a KeyError if it doesn't exist

print("Updated set:", numbers_set)
# Out:
# Numbers set: {40, 10, 20, 60, 30}
# Updated set: {40, 10, 60, 30}

# %% [markdown]
# ### Set Operations
#
# Sets support mathematical set operations like union, intersection, difference, etc.

# %%
set_a = {1, 2, 3}
set_b = {3, 4, 5}

# Union: all elements from both sets
print("Union:", set_a.union(set_b))  # or set_a | set_b

# Intersection: elements common to both
print("Intersection:", set_a.intersection(set_b))  # or set_a & set_b

# Difference: elements in set_a but not in set_b
print("Difference:", set_a.difference(set_b))  # or set_a - set_b

# Symmetric Difference: elements in either set_a or set_b, but not both
print("Symmetric Difference:", set_a.symmetric_difference(set_b))  # or set_a ^ set_b
# Out:
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference: {1, 2}
# Symmetric Difference: {1, 2, 4, 5}

# %% [markdown]
# Best Practices for Sets
#
# 1. Use sets when you need to efficiently test for membership (in check) and remove duplicates.
# 2. Avoid storing mutable items in a set—items must be hashable (immutable).
# 3. Use set operations for cleaner and more efficient code when dealing with membership and overlaps.

# %% [markdown]
# #6. Type Conversion (Casting)
#
# You can convert between data types using built-in constructor functions like int(), float(), str(), etc.

# %%
# String to int
number_str = "100"
number_int = int(number_str)
print("Converted int:", number_int, type(number_int))

# Float to int (truncates decimals)
float_num = 3.99
int_num = int(float_num)
print("Truncated int:", int_num, type(int_num))

# Int to float
int_val = 42
float_val = float(int_val)
print("Float value:", float_val, type(float_val))

# Int to string
string_val = str(int_val)
print("String value:", string_val, type(string_val))
# Out:
# Converted int: 100 <class 'int'>
# Truncated int: 3 <class 'int'>
# Float value: 42.0 <class 'float'>
# String value: 42 <class 'str'>

# %% [markdown]
# Best Practices:
#
# 1. Validate inputs before converting types to avoid ValueError.
# 2. Be aware of data loss when converting from float to int.

# %% [markdown]
# ## Practice Task

# %%
# Employee data as a list of dictionaries
employees = [
    {
        "id": 101,
        "name": "Alice Johnson",
        "department": "Engineering", 
        "salary": 75000, 
        "skills": ["Python", "SQL", "AWS"], 
        "years_of_exp": 3, 
        "projects": ["Project Alpha", "Project Beta"]
    },
    {
        "id": 102, 
        "name": "Bob Smith", 
        "department": "Marketing", 
        "salary": 65000, 
        "skills": ["SEO", "Content Writing", "Analytics"], 
        "years_of_exp": 5, 
        "projects": ["Project Gamma"]
    },
    {
        "id": 103, 
        "name": "Carol Davis", 
        "department": "Engineering", 
        "salary": 82000, 
        "skills": ["Java", "Docker", "Kubernetes", "Python"], 
        "years_of_exp": 7, 
        "projects": ["Project Alpha", "Project Delta"]
    },
    {
        "id": 104, 
        "name": "David Wilson", 
        "department": "HR", 
        "salary": 58000, 
        "skills": ["Recruitment", "Employee Relations"], 
        "years_of_exp": 2, 
        "projects": []
    },
    {
        "id": 105, 
        "name": "Eva Brown", 
        "department": "Engineering", 
        "salary": 78000, 
        "skills": ["Python", "Machine Learning", "TensorFlow"], 
        "years_of_exp": 4, 
        "projects": ["Project Beta", "Project Delta"]
    },
    {
        "id": 106, 
        "name": "Frank Miller", 
        "department": "Marketing", 
        "salary": 62000, 
        "skills": ["Social Media", "PPC", "Analytics"], 
        "years_of_exp": 3, 
        "projects": ["Project Gamma", "Project Epsilon"]
    }
]

# Department budget allocation
department_budgets = {
    "Engineering": 500000,
    "Marketing": 300000,
    "HR": 150000,
    "Finance": 200000
}

# Project teams (project_name: [employee_ids])
project_teams = {
    "Project Alpha": [101, 103],
    "Project Beta": [101, 105],
    "Project Gamma": [102, 106],
    "Project Delta": [103, 105],
    "Project Epsilon": [106]
}

# %% [markdown]
# ## Tasks:
#
# ### 1. Salary Analysis (Using Lists & Arithmetic Operations):
#
# Calculate the average salary for all employees
#
# Find the highest and lowest salary
#
# Create a list of employees who earn more than $70,000
#
# ### 2. Department Summary (Using Dictionaries & Sets):
#
# Count how many employees are in each department
#
# Calculate the total salary expenditure per department
#
# Find which departments are under budget (total salary < budget)
#
# ### 3. Skill Inventory (Using Sets & List Operations):
#
# Create a set of all unique skills across all employees
#
# Find the most common skill among employees
#
# List employees who have "Python" as one of their skills
#
# ### 4. Project Management (Using Nested Data Structures):
#
# For each project, calculate the total years of experience of its team members
#
# Find projects that have only one employee assigned
#
# Create a dictionary showing each employee and all the projects they're working on
#
# ### 5. Advanced Analysis (Combining Multiple Concepts):
#
# Find the department with the highest average salary
#
# Identify employees who are working on multiple projects
#
# Calculate what percentage of the Engineering budget is currently being used by salaries

# %% [markdown]
# ### 1. Salary Analysis (Using Lists & Arithmetic Operations):
#
# Calculate the average salary for all employees

# %%
# Get all salaries into a list

salaries = [employee['salary'] for employee in employees]
print(f"Salaries List: {salaries}")

# OR

# emp_salaries = []
# for employee in employees:
#     salaries = employee['salary']
#     emp_salaries.append(salaries)
# print(f"Salaries List: {emp_salaries}")


# Calculate average using sum() and len()
average_salary = sum(salaries) / len(salaries)
print(f"Average Salary of all Employees: ${average_salary:,.2f}")
# Out:
# Salaries List: [75000, 65000, 82000, 58000, 78000, 62000]
# Average Salary of all Employees: $70,000.00

# %% [markdown]
# Find the highest and lowest salary

# %%
highest_salary = max(salaries)
print(f"Highest salary from Employee list: {highest_salary}")

lowest_salary = min(salaries)
print(f"Lowest salary from Employee list: {lowest_salary}")
# Out:
# Highest salary from Employee list: 82000
# Lowest salary from Employee list: 58000

# %% [markdown]
# Create a list of employees who earn more than $70,000

# %%
salaries = [emp['salary'] for emp in employees]
print(f"Salaries: {salaries}")

# Create list of employees names who earn more than 70,000
high_earners = [emp['name'] for emp in employees if emp['salary'] > 70000]
print("Employees Earning > 70000")
print(high_earners)

# OR

# more_than_70000 = []
# for emp in employees:
#     if emp['salary'] > 70000:
#         emp_names = emp['name']
#         more_than_70000.append(emp_names)
# print(f"Employees who earn more than 70000: {more_than_70000}")
# Out:
# Salaries: [75000, 65000, 82000, 58000, 78000, 62000]
# Employees Earning > 70000
# ['Alice Johnson', 'Carol Davis', 'Eva Brown']

# %% [markdown]
# ### 2. Department Summary (Using Dictionaries & Sets):
#
# Count how many employees are in each department

# %%
# Total Employees names
total_employees_names = [emp['name'] for emp in employees]
print(f"Total Employee Names: {total_employees_names}")
# Total employees count
total_employees = len(total_employees_names)
print(f"Total Employees: {total_employees}")
# Out:
# Total Employee Names: ['Alice Johnson', 'Bob Smith', 'Carol Davis', 'David Wilson', 'Eva Brown', 'Frank Miller']
# Total Employees: 6

# %% [markdown]
# Calculate the total salary expenditure per department

# %%
total_departments = [emp['department'] for emp in employees]
print(f"Total Departments: {total_departments}")

department_salary_expense = {}

for emp in employees:
    dept = emp['department']
    salary = emp['salary']

    if dept in department_salary_expense:
        department_salary_expense[dept] += salary
    else:
        department_salary_expense[dept] = salary
    
print("Department-wise Salary Expense:")
for dept, salary in department_salary_expense.items():
    print(f"{dept}: {salary}")
# Out:
# Total Departments: ['Engineering', 'Marketing', 'Engineering', 'HR', 'Engineering', 'Marketing']
# Department-wise Salary Expense:
# Engineering: 235000
# Marketing: 127000
# HR: 58000

# %% [markdown]
# ### 3. Skill Inventory (Using Sets & List Operations):
#
# Create a set of all unique skills across all employees

# %%
unique_skills = {skill for emp in employees for skill in emp['skills']}
print(f"Unique Skills across all Employees: {unique_skills}")
print(f"Unique Skills (sorted): {sorted(unique_skills)}")
# Out:
# Unique Skills across all Employees: {'Java', 'SQL', 'Content Writing', 'Recruitment', 'Social Media', 'AWS', 'Employee Relations', 'PPC', 'SEO', 'Analytics', 'Kubernetes', 'Machine Learning', 'Docker', 'TensorFlow', 'Python'}
# Unique Skills (sorted): ['AWS', 'Analytics', 'Content Writing', 'Docker', 'Employee Relations', 'Java', 'Kubernetes', 'Machine Learning', 'PPC', 'Python', 'Recruitment', 'SEO', 'SQL', 'Social Media', 'TensorFlow']

# %% [markdown]
# Find the most common skill among employees
